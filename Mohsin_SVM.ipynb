# %% [markdown]
# # FakeShield — Support Vector Machine (SVM)
# **Member:** Syed Mohsin Salman (TBD)
#
# **Model:** Support Vector Machine (SVM)
#
# ---
#
# This notebook trains my assigned model on the shared preprocessed data. **Run `preprocess.ipynb` first** so the `.pkl` data files exist.

# %% [markdown]
# ## Step 1 — Import libraries

# %%
import pickle
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.svm import LinearSVC
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

print('Libraries imported!')

# %% [markdown]
# ## Step 2 — Load the shared preprocessed data
# These files come from `preprocess.ipynb`. Every member uses the same data.

# %%
X_train = pickle.load(open('X_train.pkl', 'rb'))
X_test  = pickle.load(open('X_test.pkl',  'rb'))
y_train = pickle.load(open('y_train.pkl', 'rb'))
y_test  = pickle.load(open('y_test.pkl',  'rb'))

print('Data loaded.')
print('Train shape:', X_train.shape)
print('Test shape :', X_test.shape)

# %% [markdown]
# ## Step 3 — Train the Support Vector Machine (SVM) model
# LinearSVC finds the best boundary separating the two classes. We use the linear version for speed on text.

# %%
model = LinearSVC(C=1.0, max_iter=2000, random_state=42)
print('Training... please wait.')
model.fit(X_train, y_train)
print('Training complete!')

# %% [markdown]
# ## Step 4 — Evaluate the model
# We check accuracy and a full classification report (precision, recall, F1).

# %%
y_pred = model.predict(X_test)
acc = accuracy_score(y_test, y_pred)

print(f'Accuracy: {acc * 100:.2f}%')
print()
print('Classification Report:')
print(classification_report(y_test, y_pred, target_names=['Real', 'Fake']))

# %% [markdown]
# ## Step 5 — Confusion Matrix

# %%
cm = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(6, 5))
sns.heatmap(cm, annot=True, fmt='d', cmap='Purples',
            xticklabels=['Real', 'Fake'],
            yticklabels=['Real', 'Fake'])
plt.title('Support Vector Machine (SVM) — Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Step 6 — Save the trained model
# This `.pkl` file gets uploaded to the GitHub repo.

# %%
pickle.dump(model, open('svm_model.pkl', 'wb'))
print('Model saved as svm_model.pkl')

# %% [markdown]
# ---
# ### Viva prep notes (for me)
# - **My model:** Support Vector Machine (SVM)
# - **How it works:** *(write a 2-3 line explanation in your own words)*
# - **My accuracy:** *(fill after running)*
# - **Why TF-IDF:** converts text to numbers by weighting important words
# - **Label meaning:** 1 = Fake, 0 = Real
